# %%
from google.colab import files 



uploaded = files.upload()
import csv
with open(r'atit.csv', newline='') as f:
   reader = csv.reader(f)
   data_list = list(reader)
print(data_list)
# Out:
#      <input type="file" id="files-bfb9db5e-5d6c-4129-a8d0-d6fa338ef885" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfb9db5e-5d6c-4129-a8d0-d6fa338ef885">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving atit.csv to atit.csv
# ...
